# %% [markdown]
# Dependencies

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# Look at the environment

# %%
environment_name = "CarRacing-v2"
env = gym.make(environment_name, render_mode='human')

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    truncated = False
    score = 0 
    
    while not done or truncated:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, truncated, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 9
#       6 score = 0
#       8 while not done or truncated:
# ----> 9     env.render()
#      10     action = env.action_space.sample()
#      11     n_state, reward, done, truncated, info = env.step(action)
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\wrappers\order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\wrappers\env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\envs\box2d\car_racing.py:589, in CarRacing.render(self)
#     587     return
#     588 else:
# --> 589     return self._render(self.render_mode)
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\envs\box2d\car_racing.py:617, in CarRacing._render(self, mode)
#     614 trans = pygame.math.Vector2((scroll_x, scroll_y)).rotate_rad(angle)
#     615 trans = (WINDOW_W / 2 + trans[0], WINDOW_H / 4 + trans[1])
# --> 617 self._render_road(zoom, trans, angle)
#     618 self.car.draw(
#     619     self.surf,
#     620     zoom,
#    (...)
#     623     mode not in ["state_pixels_list", "state_pixels"],
#     624 )
#     626 self.surf = pygame.transform.flip(self.surf, False, True)
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\envs\box2d\car_racing.py:661, in CarRacing._render_road(self, zoom, translation, angle)
#     653 field = [
#     654     (bounds, bounds),
#     655     (bounds, -bounds),
#     656     (-bounds, -bounds),
#     657     (-bounds, bounds),
#     658 ]
#     660 # draw background
# --> 661 self._draw_colored_polygon(
#     662     self.surf, field, self.bg_color, zoom, translation, angle, clip=False
#     663 )
#     665 # draw grass patches
#     666 grass = []
#
# File ~\PycharmProjects\pythonProject1\.venv\lib\site-packages\gymnasium\envs\box2d\car_racing.py:775, in CarRacing._draw_colored_polygon(self, surface, poly, color, zoom, translation, angle, clip)
#     769 if not clip or any(
#     770     (-MAX_SHAPE_DIM <= coord[0] <= WINDOW_W + MAX_SHAPE_DIM)
#     771     and (-MAX_SHAPE_DIM <= coord[1] <= WINDOW_H + MAX_SHAPE_DIM)
#     772     for coord in poly
#     773 ):
#     774     gfxdraw.aapolygon(self.surf, poly, color)
# --> 775     gfxdraw.filled_polygon(self.surf, poly, color)
#
# KeyboardInterrupt:

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# array([-0.35008425,  0.9896195 ,  0.03609927], dtype=float32)

# %%
env.observation_space.sample()
# Out:
# array([[[252,  59,  80],
#         [ 90,  57, 177],
#         [170,  20,  19],
#         ...,
#         [178,   0, 184],
#         [102,  49,   3],
#         [ 93, 173, 214]],
#
#        [[192,  67, 247],
#         [187, 200,  23],
#         [ 93, 101, 148],
#         ...,
#         [ 86,  33, 152],
#         [215, 230, 193],
#         [136,  95, 113]],
#
#        [[ 67,  93,   6],
#         [155, 109, 195],
#         [251, 209, 210],
#         ...,
#         [ 33, 249,  39],
#         [ 11, 115, 126],
#         [207,   0, 128]],
#
#        ...,
#
#        [[230, 200,  34],
#         [239, 153,  31],
#         [113, 135, 191],
#         ...,
#         [185, 215, 123],
#         [ 80, 212, 224],
#         [ 97, 187,   4]],
#
#        [[174, 226, 165],
#         [224,  25, 103],
#         [243, 129, 213],
#         ...,
#         [139,  32, 191],
#         [214, 165, 122],
#         [250,  95,  16]],
#
#        [[ 69,  40, 147],
#         [ 29, 254,   0],
#         [ 57, 153, 144],
#         ...,
#         [103,  57, 255],
#         [234,  33,  16],
#         [216, 119, 146]]], dtype=uint8)

# %%
env.action_space
# Out:
# Box([-1.  0.  0.], 1.0, (3,), float32)

# %%
env.observation_space
# Out:
# Box(0, 255, (96, 96, 3), uint8)

# %% [markdown]
# Training

# %%
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
env = gym.make(environment_name, render_mode=None)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\PPO_10
# -----------------------------
# | time/              |      |
# |    fps             | 28   |
# |    iterations      | 1    |
# |    time_elapsed    | 71   |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 2            |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0073313005 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.0126       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.211        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00771     |
# |    std                  | 0.978        |
# |    value_loss           | 0.546        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 3           |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010697631 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.0391      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.246       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00723    |
# |    std                  | 0.972       |
# |    value_loss           | 0.446       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 4         |
# |    time_elapsed         | 423       |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0118886 |
# |    clip_fraction        | 0.139     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.17     |
# |    explained_variance   | 0.0399    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.103     |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.0103   |
# |    std                  | 0.967     |
# |    value_loss           | 0.477     |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 5           |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012849998 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.157       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.957       |
# |    value_loss           | 0.52        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 6           |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012289455 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.939       |
# |    value_loss           | 0.469       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 7           |
# |    time_elapsed         | 773         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011645721 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.931       |
# |    value_loss           | 0.447       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 8           |
# |    time_elapsed         | 892         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015599357 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0601      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.918       |
# |    value_loss           | 0.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 9           |
# |    time_elapsed         | 1009        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018300183 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.91        |
# |    value_loss           | 0.279       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 10          |
# |    time_elapsed         | 1128        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.020524763 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00553     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.904       |
# |    value_loss           | 0.312       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 11          |
# |    time_elapsed         | 1247        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.018524932 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.892       |
# |    value_loss           | 0.239       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 12          |
# |    time_elapsed         | 1366        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.024192514 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0418      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.884       |
# |    value_loss           | 0.19        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 13          |
# |    time_elapsed         | 1485        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.026542958 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00994     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.877       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 14          |
# |    time_elapsed         | 1604        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025900248 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00594     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.875       |
# |    value_loss           | 0.177       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 15          |
# |    time_elapsed         | 1723        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021935496 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00231     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.865       |
# |    value_loss           | 0.138       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 16         |
# |    time_elapsed         | 1846       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02084062 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.8       |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0453     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0222    |
# |    std                  | 0.858      |
# |    value_loss           | 0.224      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 17          |
# |    time_elapsed         | 1980        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.024974113 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0456      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.844       |
# |    value_loss           | 0.195       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 18          |
# |    time_elapsed         | 2106        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.031873427 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 0.832       |
# |    value_loss           | 0.213       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 19         |
# |    time_elapsed         | 2228       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03547414 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.68      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.011      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0333    |
# |    std                  | 0.828      |
# |    value_loss           | 0.202      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 20          |
# |    time_elapsed         | 2350        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.035401523 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0295     |
# |    std                  | 0.812       |
# |    value_loss           | 0.174       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 21         |
# |    time_elapsed         | 2467       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03301364 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000522   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0355    |
# |    std                  | 0.806      |
# |    value_loss           | 0.24       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 22          |
# |    time_elapsed         | 2587        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.036836553 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00377     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0396     |
# |    std                  | 0.793       |
# |    value_loss           | 0.199       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 23          |
# |    time_elapsed         | 2707        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.036126103 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0363      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.782       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 24          |
# |    time_elapsed         | 2825        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.033055987 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00777    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0365     |
# |    std                  | 0.77        |
# |    value_loss           | 0.154       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 25         |
# |    time_elapsed         | 2948       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04938639 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0235    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0399    |
# |    std                  | 0.764      |
# |    value_loss           | 0.248      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 26         |
# |    time_elapsed         | 3070       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.04847319 |
# |    clip_fraction        | 0.33       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0258    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.033     |
# |    std                  | 0.762      |
# |    value_loss           | 0.173      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 27          |
# |    time_elapsed         | 3193        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.049237035 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00285    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0401     |
# |    std                  | 0.755       |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 28          |
# |    time_elapsed         | 3312        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.036661655 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0276      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0412     |
# |    std                  | 0.75        |
# |    value_loss           | 0.409       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 29         |
# |    time_elapsed         | 3429       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.03757341 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.33      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00531   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0405    |
# |    std                  | 0.736      |
# |    value_loss           | 0.234      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 30          |
# |    time_elapsed         | 3548        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.062803596 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0371     |
# |    std                  | 0.728       |
# |    value_loss           | 0.275       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 31          |
# |    time_elapsed         | 3665        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.052203048 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0401     |
# |    std                  | 0.719       |
# |    value_loss           | 0.352       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 32         |
# |    time_elapsed         | 3783       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.05242347 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0198    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0336    |
# |    std                  | 0.717      |
# |    value_loss           | 0.223      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 33          |
# |    time_elapsed         | 3902        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.075304374 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0274     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0364     |
# |    std                  | 0.709       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 34         |
# |    time_elapsed         | 4020       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.09937477 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00101   |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0383    |
# |    std                  | 0.696      |
# |    value_loss           | 0.173      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 35         |
# |    time_elapsed         | 4138       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.05406195 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.025      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.042     |
# |    std                  | 0.689      |
# |    value_loss           | 0.309      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 36          |
# |    time_elapsed         | 4257        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.049075518 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0522      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.685       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 37          |
# |    time_elapsed         | 4376        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.051315382 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0403      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0412     |
# |    std                  | 0.67        |
# |    value_loss           | 0.268       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 38          |
# |    time_elapsed         | 4496        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.045538403 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0618      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.657       |
# |    value_loss           | 0.204       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 39         |
# |    time_elapsed         | 4612       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.06591772 |
# |    clip_fraction        | 0.37       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.94      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0734     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0325    |
# |    std                  | 0.648      |
# |    value_loss           | 0.335      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 40          |
# |    time_elapsed         | 4731        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.052993096 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00293    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 0.643       |
# |    value_loss           | 0.336       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 41         |
# |    time_elapsed         | 4848       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.05255556 |
# |    clip_fraction        | 0.334      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00646    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0378    |
# |    std                  | 0.639      |
# |    value_loss           | 0.26       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 42          |
# |    time_elapsed         | 4966        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.061511006 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0444      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.035      |
# |    std                  | 0.633       |
# |    value_loss           | 0.408       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 43         |
# |    time_elapsed         | 5087       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.05053649 |
# |    clip_fraction        | 0.34       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.81      |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0683     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0363    |
# |    std                  | 0.622      |
# |    value_loss           | 0.272      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 44          |
# |    time_elapsed         | 5207        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.060645636 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00514     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0373     |
# |    std                  | 0.621       |
# |    value_loss           | 0.285       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 45        |
# |    time_elapsed         | 5330      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0610967 |
# |    clip_fraction        | 0.337     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.75     |
# |    explained_variance   | 0.984     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0564    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.038    |
# |    std                  | 0.611     |
# |    value_loss           | 0.197     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 46         |
# |    time_elapsed         | 5454       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07498935 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000564   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0393    |
# |    std                  | 0.599      |
# |    value_loss           | 0.264      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 47          |
# |    time_elapsed         | 5577        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.082072765 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0497     |
# |    std                  | 0.595       |
# |    value_loss           | 0.213       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 48         |
# |    time_elapsed         | 5696       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.05320116 |
# |    clip_fraction        | 0.352      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.63      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0293    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.038     |
# |    std                  | 0.59       |
# |    value_loss           | 0.237      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 49          |
# |    time_elapsed         | 5816        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.042398307 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 0.579       |
# |    value_loss           | 0.299       |
# -----------------------------------------

# %%
car_path = os.path.join('Training', 'Saved Models', 'car_model1')

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\PPO_12
# -----------------------------
# | time/              |      |
# |    fps             | 28   |
# |    iterations      | 1    |
# |    time_elapsed    | 72   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 2           |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.046060868 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0831      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.578       |
# |    value_loss           | 0.361       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 3           |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.066599935 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0278      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0438     |
# |    std                  | 0.572       |
# |    value_loss           | 0.298       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 4          |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.15089867 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.51      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.136      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0303    |
# |    std                  | 0.569      |
# |    value_loss           | 0.401      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 5          |
# |    time_elapsed         | 554        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.13553044 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00203    |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0505    |
# |    std                  | 0.562      |
# |    value_loss           | 0.513      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 6           |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.055561814 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0571      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0379     |
# |    std                  | 0.561       |
# |    value_loss           | 0.393       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 7           |
# |    time_elapsed         | 795         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.061910465 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00275     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0459     |
# |    std                  | 0.557       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 8          |
# |    time_elapsed         | 915        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.06101858 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.43      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00676   |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.041     |
# |    std                  | 0.558      |
# |    value_loss           | 0.274      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 9          |
# |    time_elapsed         | 1034       |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.10735756 |
# |    clip_fraction        | 0.348      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.43      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0554    |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0414    |
# |    std                  | 0.554      |
# |    value_loss           | 0.295      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 10         |
# |    time_elapsed         | 1155       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.06894618 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0677     |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0429    |
# |    std                  | 0.542      |
# |    value_loss           | 0.588      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 11         |
# |    time_elapsed         | 1273       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.11133593 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.33      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.325      |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0326    |
# |    std                  | 0.536      |
# |    value_loss           | 0.379      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 12          |
# |    time_elapsed         | 1393        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.071315944 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0979      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.032      |
# |    std                  | 0.532       |
# |    value_loss           | 1.14        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 13         |
# |    time_elapsed         | 1532       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.06384382 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.274      |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0291    |
# |    std                  | 0.53       |
# |    value_loss           | 1.48       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 14          |
# |    time_elapsed         | 1655        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.054884195 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.529       |
# |    value_loss           | 1.34        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 15         |
# |    time_elapsed         | 1776       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.09516978 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.561      |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0202    |
# |    std                  | 0.528      |
# |    value_loss           | 2.73       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 16        |
# |    time_elapsed         | 1900      |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.6981659 |
# |    clip_fraction        | 0.5       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.25     |
# |    explained_variance   | 0.82      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.328     |
# |    n_updates            | 640       |
# |    policy_gradient_loss | -0.00826  |
# |    std                  | 0.528     |
# |    value_loss           | 6.25      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 17         |
# |    time_elapsed         | 2024       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.08148199 |
# |    clip_fraction        | 0.501      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.373      |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0131    |
# |    std                  | 0.527      |
# |    value_loss           | 5.14       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 18         |
# |    time_elapsed         | 2149       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.10187195 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.23       |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.526      |
# |    value_loss           | 5.85       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 19          |
# |    time_elapsed         | 2282        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.089021385 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.672       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.00188     |
# |    std                  | 0.525       |
# |    value_loss           | 4.64        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 20         |
# |    time_elapsed         | 2402       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.11343311 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.24      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.359      |
# |    n_updates            | 680        |
# |    policy_gradient_loss | 0.00453    |
# |    std                  | 0.525      |
# |    value_loss           | 3.94       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 21        |
# |    time_elapsed         | 2534      |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0638234 |
# |    clip_fraction        | 0.395     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.23     |
# |    explained_variance   | 0.974     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.491     |
# |    n_updates            | 690       |
# |    policy_gradient_loss | 0.0153    |
# |    std                  | 0.523     |
# |    value_loss           | 3.09      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 22         |
# |    time_elapsed         | 2669       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.17134045 |
# |    clip_fraction        | 0.434      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.256      |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.000347  |
# |    std                  | 0.523      |
# |    value_loss           | 4.02       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 23          |
# |    time_elapsed         | 2805        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.070016816 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.0126      |
# |    std                  | 0.522       |
# |    value_loss           | 7.18        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 24         |
# |    time_elapsed         | 2942       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.09885657 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2          |
# |    n_updates            | 720        |
# |    policy_gradient_loss | 0.00785    |
# |    std                  | 0.522      |
# |    value_loss           | 11.3       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 25        |
# |    time_elapsed         | 3081      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 1.3548405 |
# |    clip_fraction        | 0.489     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.22     |
# |    explained_variance   | 0.912     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.03      |
# |    n_updates            | 730       |
# |    policy_gradient_loss | -0.00467  |
# |    std                  | 0.52      |
# |    value_loss           | 13.8      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 26         |
# |    time_elapsed         | 3202       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.26297092 |
# |    clip_fraction        | 0.545      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.25       |
# |    n_updates            | 740        |
# |    policy_gradient_loss | 0.0156     |
# |    std                  | 0.522      |
# |    value_loss           | 12.7       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 27        |
# |    time_elapsed         | 3325      |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.5999346 |
# |    clip_fraction        | 0.57      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.22     |
# |    explained_variance   | 0.966     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.227     |
# |    n_updates            | 750       |
# |    policy_gradient_loss | 0.0154    |
# |    std                  | 0.52      |
# |    value_loss           | 1.78      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 28         |
# |    time_elapsed         | 3447       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.16064498 |
# |    clip_fraction        | 0.506      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.43       |
# |    n_updates            | 760        |
# |    policy_gradient_loss | 0.0195     |
# |    std                  | 0.52       |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 29         |
# |    time_elapsed         | 3569       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.12841356 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14       |
# |    n_updates            | 770        |
# |    policy_gradient_loss | 0.0133     |
# |    std                  | 0.518      |
# |    value_loss           | 10.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 30         |
# |    time_elapsed         | 3694       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.15900823 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.69       |
# |    n_updates            | 780        |
# |    policy_gradient_loss | 0.0141     |
# |    std                  | 0.52       |
# |    value_loss           | 5.61       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 31        |
# |    time_elapsed         | 3814      |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 1.6373749 |
# |    clip_fraction        | 0.597     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.22     |
# |    explained_variance   | 0.789     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.332     |
# |    n_updates            | 790       |
# |    policy_gradient_loss | 0.00656   |
# |    std                  | 0.52      |
# |    value_loss           | 15.4      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 32         |
# |    time_elapsed         | 3934       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.15919432 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.268      |
# |    n_updates            | 800        |
# |    policy_gradient_loss | 0.0203     |
# |    std                  | 0.519      |
# |    value_loss           | 4.29       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 33         |
# |    time_elapsed         | 4052       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.15069786 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.327      |
# |    n_updates            | 810        |
# |    policy_gradient_loss | 0.00286    |
# |    std                  | 0.519      |
# |    value_loss           | 1.87       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 34         |
# |    time_elapsed         | 4172       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.09026359 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0599     |
# |    n_updates            | 820        |
# |    policy_gradient_loss | 0.0105     |
# |    std                  | 0.513      |
# |    value_loss           | 1.92       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 35         |
# |    time_elapsed         | 4294       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.12883896 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.263      |
# |    n_updates            | 830        |
# |    policy_gradient_loss | 0.00801    |
# |    std                  | 0.517      |
# |    value_loss           | 2.31       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 36          |
# |    time_elapsed         | 4415        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.080929756 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.0268      |
# |    std                  | 0.52        |
# |    value_loss           | 4.25        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 37         |
# |    time_elapsed         | 4538       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.12174391 |
# |    clip_fraction        | 0.457      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.571      |
# |    n_updates            | 850        |
# |    policy_gradient_loss | 0.011      |
# |    std                  | 0.518      |
# |    value_loss           | 5.36       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 38         |
# |    time_elapsed         | 4659       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.48313653 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.08       |
# |    n_updates            | 860        |
# |    policy_gradient_loss | 0.00611    |
# |    std                  | 0.519      |
# |    value_loss           | 21.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 39         |
# |    time_elapsed         | 4789       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.11076381 |
# |    clip_fraction        | 0.449      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.534      |
# |    n_updates            | 870        |
# |    policy_gradient_loss | 0.0105     |
# |    std                  | 0.52       |
# |    value_loss           | 8.3        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 40         |
# |    time_elapsed         | 4908       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.14156371 |
# |    clip_fraction        | 0.516      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.0171     |
# |    std                  | 0.52       |
# |    value_loss           | 13.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 41         |
# |    time_elapsed         | 5031       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.24638212 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.487      |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.000261  |
# |    std                  | 0.524      |
# |    value_loss           | 5.65       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 42         |
# |    time_elapsed         | 5163       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.19342683 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.26      |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.774      |
# |    n_updates            | 900        |
# |    policy_gradient_loss | 0.0507     |
# |    std                  | 0.526      |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 43         |
# |    time_elapsed         | 5289       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.18949375 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.27      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.28       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.0149     |
# |    std                  | 0.527      |
# |    value_loss           | 13.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 44          |
# |    time_elapsed         | 5416        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.102645054 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.799       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.0139      |
# |    std                  | 0.527       |
# |    value_loss           | 4.13        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 45         |
# |    time_elapsed         | 5540       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.41954494 |
# |    clip_fraction        | 0.572      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.29      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.65       |
# |    n_updates            | 930        |
# |    policy_gradient_loss | 0.00694    |
# |    std                  | 0.53       |
# |    value_loss           | 10.8       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 46        |
# |    time_elapsed         | 5665      |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.2409519 |
# |    clip_fraction        | 0.521     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.3      |
# |    explained_variance   | 0.913     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.628     |
# |    n_updates            | 940       |
# |    policy_gradient_loss | -0.00155  |
# |    std                  | 0.53      |
# |    value_loss           | 10.7      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 47         |
# |    time_elapsed         | 5790       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.15336455 |
# |    clip_fraction        | 0.562      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.411      |
# |    n_updates            | 950        |
# |    policy_gradient_loss | 0.0221     |
# |    std                  | 0.526      |
# |    value_loss           | 5.9        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 48         |
# |    time_elapsed         | 5920       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.14570284 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.27      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.344      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | 0.00116    |
# |    std                  | 0.525      |
# |    value_loss           | 4.72       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 49         |
# |    time_elapsed         | 6053       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.16410783 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.26      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.758      |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.0138     |
# |    std                  | 0.526      |
# |    value_loss           | 11.1       |
# ----------------------------------------

# %%
model.save(car_path)

# %%
model = PPO.load(car_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# Validation

# %%
env = gym.make(environment_name, render_mode='human')
env = DummyVecEnv([lambda: env])

# %%
model = PPO.load(car_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (183.7277955338359, 122.85435607001057)
